# %% [markdown]
# Trainingsdaten

# %%
import json
import regex as re
import statistics
import matplotlib.pyplot as plt
from collections import Counter

# %%
Path = r"shakespeare.json"

# %%
text_entries = []

try:
    with open(Path, "r") as json_file:
        for line in json_file:
            try:
                json_data = json.loads(line)

                if 'text_entry' in json_data:
                    text_entries.append(json_data['text_entry'])

            except json.JSONDecodeError:
                print("error")
    print(f"Text Zeilen:{len(text_entries)}")


except FileNotFoundError:
    print(f"Die Datei {json_file_path} wurde nicht gefunden.")
except Exception as e:
    print(f"Ein Fehler ist aufgetreten: {str(e)}")
# Out:
# Text Zeilen:111396

# %% [markdown]
# 1. Länge der Redebeiträge

# %%
n = []
for i in text_entries:
    l = i.split(" ")
    n.append(len(l))

# %% [markdown]
# 2. Median Länge Redebeiträge

# %%
median = statistics.median(n)
print(f"Median Länge Redebeiträge:{median}")
# Out:
# Median Länge Redebeiträge:8.0

# %% [markdown]
# 3. Anzahl der Tokens

# %%
print(f"Anzahl der Tokens: {sum(n)}")
# Out:
# Anzahl der Tokens: 815988

# %% [markdown]
# 4. Abkürzungen

# %%
regex = r"\b[IVXLCDM]+|Scene|Act\b"

abbreviation_list = []


for i in text_entries:
    matches = re.findall(regex, i)
    if(len(matches)>1):
        abbreviation_list.append(matches)
    
print(f"Abkürzungen: {abbreviation_list}")
# Out:
# Abkürzungen: [['I', 'L'], ['L', 'L'], ['M', 'M'], ['I', 'L'], ['I', 'M'], ['II', 'L'], ['D', 'I'], ['I', 'L', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'I', 'I'], ['I', 'I'], ['L', 'I'], ['I', 'I'], ['I', 'I', 'I'], ['L', 'I'], ['I', 'I'], ['III', 'L'], ['M', 'I'], ['I', 'I'], ['L', 'M'], ['M', 'L'], ['I', 'I'], ['I', 'M'], ['I', 'M'], ['I', 'I'], ['I', 'L', 'M'], ['I', 'C'], ['L', 'I'], ['I', 'C'], ['C', 'M'], ['M', 'I'], ['I', 'I'], ['I', 'I'], ['C', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I', 'I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'L'], ['M', 'M'], ['D', 'I'], ['I', 'I'], ['C', 'C'], ['I', 'I'], ['I', 'M'], ['D', 'I'], ['I', 'I'], ['L', 'I'], ['I', 'D'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'I'], ['L', 'I'], ['L', 'M', 'I'], ['L', 'I'], ['D', 'M'], ['I', 'I', 'I'], ['I', 'I'], ['L', 'I'], ['I', 'I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['M', 'I', 'I'], ['I', 'I'], ['I', 'I'], ['D', 'D'], ['M', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'M'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'C'], ['I', 'I'], ['M', 'I'], ['I', 'I'], ['I', 'L', 'I'], ['C', 'I'], ['C', 'L', 'M'], ['II', 'L'], ['L', 'I'], ['I', 'I'], ['I', 'I'], ['M', 'I'], ['D', 'D'], ['D', 'M'], ['L', 'M'], ['L', 'L'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['D', 'I'], ['I', 'I'], ['D', 'I'], ['I', 'I'], ['I', 'I', 'I'], ['D', 'I'], ['I', 'I'], ['I', 'I'], ['M', 'I'], ['I', 'I', 'I'], ['M', 'M'], ['I', 'I'], ['D', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'L'], ['I', 'I'], ['M', 'V'], ['I', 'I'], ['II', 'C'], ['I', 'I', 'I'], ['M', 'L', 'I'], ['D', 'V'], ['D', 'D'], ['C', 'I'], ['D', 'L'], ['M', 'L', 'I', 'M'], ['D', 'L', 'M'], ['M', 'V', 'L'], ['L', 'L'], ['I', 'IV'], ['L', 'L'], ['D', 'I'], ['D', 'L'], ['D', 'L'], ['L', 'D'], ['I', 'M'], ['C', 'I'], ['L', 'I'], ['D', 'I'], ['I', 'L', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'L'], ['L', 'L'], ['I', 'I'], ['M', 'L'], ['C', 'I'], ['L', 'I'], ['I', 'L'], ['I', 'D'], ['C', 'I', 'C'], ['I', 'I'], ['M', 'C', 'I'], ['I', 'I', 'M'], ['I', 'I'], ['D', 'D'], ['M', 'I'], ['I', 'I'], ['C', 'I', 'I'], ['I', 'I', 'I'], ['L', 'L'], ['I', 'I'], ['I', 'I'], ['D', 'L', 'L'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['IV', 'L', 'L', 'V'], ['I', 'C'], ['L', 'D'], ['D', 'I'], ['D', 'M', 'D'], ['M', 'I'], ['D', 'C'], ['I', 'I'], ['L', 'L'], ['I', 'D'], ['I', 'I'], ['D', 'I'], ['D', 'I'], ['D', 'C'], ['I', 'I'], ['D', 'I'], ['L', 'I'], ['I', 'I'], ['C', 'I'], ['I', 'I'], ['III', 'L'], ['M', 'D'], ['L', 'I'], ['D', 'C'], ['I', 'I'], ['D', 'I'], ['M', 'L'], ['C', 'I'], ['C', 'I'], ['I', 'I'], ['I', 'I'], ['D', 'I'], ['C', 'L'], ['I', 'I', 'I'], ['I', 'I'], ['D', 'L'], ['D', 'I'], ['C', 'I'], ['M', 'I'], ['I', 'I', 'I'], ['L', 'C'], ['C', 'I'], ['C', 'L'], ['I', 'D'], ['M', 'I'], ['I', 'D'], ['I', 'I'], ['III', 'C'], ['M', 'I'], ['I', 'I'], ['M', 'I'], ['IV', 'L'], ['V', 'L'], ['I', 'I'], ['M', 'V'], ['I', 'I', 'I'], ['I', 'I'], ['I', 'I'], ['L', 'D', 'C'], ['M', 'V', 'I'], ['I', 'I'], ['C', 'I'], ['V', 'L'], ['L', 'M'], ['D', 'I'], ['M', 'C'], ['L', 'D', 'C'], ['L', 'D'], ['I', 'L'], ['I', 'L'], ['I', 'I'], ['M', 'I', 'I'], ['C', 'L'], ['D', 'I'], ['L', 'I'], ['I', 'I'], ['C', 'D'], ['L', 'C'], ['I', 'D'], ['D', 'I'], ['D', 'C'], ['M', 'I'], ['L', 'C'], ['C', 'L'], ['I', 'D'], ['C', 'I'], ['VI', 'V'], ['I', 'L'], ['I', 'I'], ['D', 'I'], ['I', 'L'], ['M', 'I', 'C'], ['I', 'I'], ['C', 'I'], ['I', 'I'], ['C', 'C'], ['I', 'I'], ['M', 'L', 'I'], ['I', 'D'], ['I', 'I'], ['C', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['M', 'I'], ['I', 'I'], ['C', 'L'], ['I', 'I'], ['V', 'L'], ['L', 'L', 'V'], ['L', 'C', 'L'], ['I', 'L'], ['C', 'C', 'L'], ['C', 'L'], ['C', 'L'], ['C', 'C'], ['L', 'L'], ['D', 'I', 'I'], ['C', 'D'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'I'], ['I', 'L', 'M'], ['D', 'M'], ['M', 'I'], ['L', 'I'], ['I', 'I'], ['IV', 'C'], ['M', 'I'], ['D', 'I'], ['C', 'I ...

# %% [markdown]
# 5. Kontraktionen am Beispiel he's

# %%
regex = r" hes "

abbreviation_list = []


for i in text_entries:
    matches = re.findall(regex, i)
    if(len(matches)>1):
        abbreviation_list.append(matches)
    
print(f"Kontraktion am Beispiel he's: {abbreviation_list}")
# Out:
# Kontraktion am Beispiel he's: [[' hes ', ' hes '], [' hes ', ' hes '], [' hes ', ' hes ', ' hes '], [' hes ', ' hes ', ' hes '], [' hes ', ' hes ']]

# %% [markdown]
# 6. Zeichnung eines Plots zur Darstellung der Worthäufigkeiten

# %%
b = []

for i in text_entries:
    l = i.split(" ")
    for a in l:
        b.append(a)

# %%
häufigkeiten = Counter(b)

sortierte_häufigkeiten = häufigkeiten.most_common()

wörter, frequenzen = zip(*sortierte_häufigkeiten)

# %%
plt.figure(figsize=(10, 6))

plt.ylim(0, 2000)

plt.xticks(range(0, len(wörter), 1000), rotation=90)

plt.bar(wörter, frequenzen)
plt.xlabel('Wort')
plt.ylabel('Häufigkeit')
plt.title('Häufigkeit der Wörter')
plt.tight_layout()
plt.savefig('balkendiagramm.png')

plt.show()
